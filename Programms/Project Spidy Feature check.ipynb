# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0,1,num=51)
fx = []
for s in x:
    fx.append(-8.97149474605567 *s**3+ 16.05884151811911 *s**2+ -8.057740765969402 *s+ 1.538295459111207)

# %%
inp = []
temp = []
for i in range(len(x)):
    temp.append((x[i],fx[i]))
inp.append(temp)
print(inp)
# Out:
# [[(0.0, 1.538295459111207), (0.02, 1.3834924084410982), (0.04, 1.241105799237674), (0.06, 1.1107049997531235), (0.08, 0.9918593782396367), (0.1, 0.8841383029494021), (0.12, 0.7871111421346098), (0.14, 0.7003472640474484), (0.16, 0.6234160369401078), (0.18, 0.555886829064777), (0.2, 0.4973290086736455), (0.22, 0.4473119440189026), (0.24, 0.40540500335273766), (0.26, 0.37117755492733995), (0.28, 0.3441989669948986), (0.3, 0.3240386078076032), (0.32, 0.3102658456176428), (0.34, 0.30245004867720726), (0.36, 0.30016058523848543), (0.38, 0.30296682355366666), (0.4, 0.31043813187494074), (0.42, 0.3221438784544963), (0.44, 0.3376534315445232), (0.46, 0.35653615939721073), (0.48, 0.3783614302647482), (0.5, 0.4026986123993246), (0.52, 0.4291170740531296), (0.54, 0.45718618347835127), (0.56, 0.4864753089271825), (0.58, 0.5165538186518082), (0.6, 0.5469910809044203), (0.62, 0.5773564639372082), (0.64, 0.6072193360023594), (0.66, 0.6361490653520634), (0.68, 0.6637150202385143), (0.700000000000000
# ...

# %%
s = 0.77
check = -8.97149474605567 *s**3+ 16.05884151811911 *s**2+ -8.057740765969402 *s+ 1.538295459111207
plt.scatter(s,check)
plt.plot(x,fx)
plt.axis([0.765,0.775,0.755,0.765])
#plt.axis('off')
plt.show()
